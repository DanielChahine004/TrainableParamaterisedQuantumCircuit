# %%
import struct
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
from torch.utils.data import Dataset, DataLoader
import os
from typing import Union, List, Optional


class MNISTLoader:
    def __init__(self, images_path, labels_path):
        # Verify files exist
        if not os.path.exists(images_path):
            raise FileNotFoundError(f"Images file not found at: {images_path}")
        if not os.path.exists(labels_path):
            raise FileNotFoundError(f"Labels file not found at: {labels_path}")
            
        self.images = self._read_images(images_path)
        self.labels = self._read_labels(labels_path)
        
    def _read_images(self, path):
        with open(path, 'rb') as f:
            # Read header info
            magic = struct.unpack('>I', f.read(4))[0]
            num_images = struct.unpack('>I', f.read(4))[0]
            num_rows = struct.unpack('>I', f.read(4))[0]
            num_cols = struct.unpack('>I', f.read(4))[0]
            
            # Read image data
            image_data = np.frombuffer(f.read(), dtype=np.uint8)
            image_data = image_data.reshape(num_images, 1, num_rows, num_cols)
            
            # Normalize to [0,1] range
            return image_data.astype(np.float32) / 255.0

    def _read_labels(self, path):
        with open(path, 'rb') as f:
            # Read header info
            magic = struct.unpack('>I', f.read(4))[0]
            num_labels = struct.unpack('>I', f.read(4))[0]
            
            # Read label data
            return np.frombuffer(f.read(), dtype=np.uint8)


class MNISTDataset(Dataset):
    def __init__(self, images, labels):
        self.images = torch.FloatTensor(images)
        self.labels = torch.LongTensor(labels)
        
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.images[idx], self.labels[idx]


def load_mnist(train=True, batch_size=32, shuffle=True):
    """
    Load MNIST dataset from local files
    
    Args:
        train (bool): If True, load training data, else load test data
        batch_size (int): Size of batches to return
        shuffle (bool): Whether to shuffle the data
        
    Returns:
        DataLoader: PyTorch DataLoader object
    """
    base_path = r'D:\Programming\Python\PennyLane\TrainableParamaterisedQuantumCircuit\MNIST_Data'
    
    if train:
        images_path = os.path.join(base_path, 'train-images.idx3-ubyte')
        labels_path = os.path.join(base_path, 'train-labels.idx1-ubyte')
    else:
        images_path = os.path.join(base_path, 't10k-images.idx3-ubyte')
        labels_path = os.path.join(base_path, 't10k-labels.idx1-ubyte')
    
    # Load the data
    loader = MNISTLoader(images_path, labels_path)
    
    # Create dataset
    dataset = MNISTDataset(loader.images, loader.labels)
    
    # Create dataloader with more conservative settings
    return DataLoader(
        dataset=dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        num_workers=0,
        pin_memory=True,
        persistent_workers=False,  # Disabled persistent workers
        prefetch_factor=None  # Removed prefetch
    )


def show_batch_images(images: torch.Tensor, 
                     labels: torch.Tensor, 
                     indices: Optional[Union[List[int], np.ndarray]] = None,
                     grid_size: tuple = (4, 4),
                     figsize: tuple = (12, 12)) -> None:
    """
    Display selected images from a batch of MNIST images.
    
    Args:
        images (torch.Tensor): Batch of images with shape [batch_size, channels, height, width]
        labels (torch.Tensor): Corresponding labels
        indices (list or np.ndarray, optional): Specific indices to display. If None, displays first n images that fit in grid
        grid_size (tuple): Size of the display grid (rows, cols)
        figsize (tuple): Figure size in inches (width, height)
        
    Returns:
        None (displays the plot)
    """
    # Ensure images are on CPU and convert to numpy if needed
    if images.device != 'cpu':
        images = images.cpu()
    if labels.device != 'cpu':
        labels = labels.cpu()
    
    # Calculate total spots in grid
    total_spots = grid_size[0] * grid_size[1]
    
    # If no indices provided, use first n images that fit in grid
    if indices is None:
        indices = list(range(min(total_spots, len(images))))
    else:
        # Ensure indices are within bounds
        indices = [i for i in indices if i < len(images)]
        if not indices:
            raise ValueError("No valid indices provided")
    
    # Create figure and axes
    fig, axes = plt.subplots(grid_size[0], grid_size[1], figsize=figsize)
    fig.suptitle('MNIST Digits from Batch', fontsize=16, y=0.95)
    
    # Flatten axes for easier indexing
    axes = axes.ravel()
    
    # Plot each selected image
    for idx, ax_idx in enumerate(range(total_spots)):
        ax = axes[ax_idx]
        
        if idx < len(indices):
            # Get image and label
            img = images[indices[idx]].squeeze()
            label = labels[indices[idx]].item()
            
            # Display image
            ax.imshow(img, cmap='gray')
            ax.set_title(f'Label: {label}')
        else:
            # Hide empty subplots
            ax.axis('off')
            continue
            
        # Remove ticks
        ax.set_xticks([])
        ax.set_yticks([])
    
    # Adjust layout and display
    plt.tight_layout()
    plt.show()


class QCHNN(torch.nn.Module):
    def __init__(self):
        super().__init__()
        
         # First convolutional layer
        self.conv1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, padding=1),  # 1 input channel (grayscale), 32 output channels
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)  # Reduce spatial dimensions by half
        )
        
        # Second convolutional layer
        self.conv2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, padding=1),  # 32 input channels, 64 output channels
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        
        # Fully connected layers
        self.linears = nn.Sequential(
            nn.Flatten(),  # Flatten the 2D features to 1D
            nn.Linear(64 * 7 * 7, 128),  # Assuming input image is 28x28 (like MNIST)
            nn.ReLU(),
            nn.Linear(128, 10),
            nn.ReLU(), 
            nn.Linear(10,10)
        )
        
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.linears(x)  # shape: (batch_size, 10)
        
        return x.softmax(dim=1)

# %%
# First check if CUDA is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

model = QCHNN().to(device).double()
# Out:
# Using device: cuda

# %%
train_loader = load_mnist(train=True, batch_size=128, shuffle=True)
test_loader = load_mnist(train=False, batch_size=128, shuffle=False)

for batch_idx, (images, labels) in enumerate(train_loader):
    print(f"Batch {batch_idx}")
    print(f"Images shape: {images.shape}")  # Should be [batch_size, 1, 28, 28]
    print(f"Labels shape: {labels.shape}")  # Should be [batch_size]
    show_batch_images(images, labels, figsize=(5,5))
    break  # Just show first batch
# Out:
# Batch 0
# Images shape: torch.Size([128, 1, 28, 28])
# Labels shape: torch.Size([128])

# %%
optimiser = torch.optim.Adamax(model.parameters(), lr=0.01)
criterion = nn.MSELoss()
epochs = 10

for epoch in range(epochs):
    for batch_idx, (images, labels) in enumerate(test_loader):
        
        images = images.to(device).double()
        labels_one_hot = torch.nn.functional.one_hot(labels, 10).to(device).double()
        
        optimiser.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels_one_hot)
        loss.backward()
        optimiser.step()
        
        if epoch % 1 == 0:
            print(f'[Epoch {epoch + 1}] [Batch {batch_idx}] Loss: {loss.item():.5f}')
# Out:
# [Epoch 1] [Batch 0] Loss: 0.09011
# [Epoch 1] [Batch 1] Loss: 0.09182
# [Epoch 1] [Batch 2] Loss: 0.09083
# [Epoch 1] [Batch 3] Loss: 0.08974
# [Epoch 1] [Batch 4] Loss: 0.09032
# [Epoch 1] [Batch 5] Loss: 0.08987
# [Epoch 1] [Batch 6] Loss: 0.08968
# [Epoch 1] [Batch 7] Loss: 0.08932
# [Epoch 1] [Batch 8] Loss: 0.08952
# [Epoch 1] [Batch 9] Loss: 0.08895
# [Epoch 1] [Batch 10] Loss: 0.08767
# [Epoch 1] [Batch 11] Loss: 0.08778
# [Epoch 1] [Batch 12] Loss: 0.08662
# [Epoch 1] [Batch 13] Loss: 0.08578
# [Epoch 1] [Batch 14] Loss: 0.08304
# [Epoch 1] [Batch 15] Loss: 0.08293
# [Epoch 1] [Batch 16] Loss: 0.08302
# [Epoch 1] [Batch 17] Loss: 0.08119
# [Epoch 1] [Batch 18] Loss: 0.07982
# [Epoch 1] [Batch 19] Loss: 0.07627
# [Epoch 1] [Batch 20] Loss: 0.07594
# [Epoch 1] [Batch 21] Loss: 0.07759
# [Epoch 1] [Batch 22] Loss: 0.07600
# [Epoch 1] [Batch 23] Loss: 0.07180
# [Epoch 1] [Batch 24] Loss: 0.07142
# [Epoch 1] [Batch 25] Loss: 0.06966
# [Epoch 1] [Batch 26] Loss: 0.06373
# [Epoch 1] [Batch 27] Loss: 0.07313
# [Epoch 1] [Batch 28] Loss: 0.06141
# [Epoch 1] [Batch 29] Loss: 0.07095
# [Epoch 1] [Batch 30] Loss: 0.06024
# [Epoch 1] [Batch 31] Loss: 0.05733
# [Epoch 1] [Batch 32] Loss: 0.05527
# [Epoch 1] [Batch 33] Loss: 0.05671
# [Epoch 1] [Batch 34] Loss: 0.05996
# [Epoch 1] [Batch 35] Loss: 0.05661
# [Epoch 1] [Batch 36] Loss: 0.04709
# [Epoch 1] [Batch 37] Loss: 0.05898
# [Epoch 1] [Batch 38] Loss: 0.05008
# [Epoch 1] [Batch 39] Loss: 0.05270
# [Epoch 1] [Batch 40] Loss: 0.05156
# [Epoch 1] [Batch 41] Loss: 0.04719
# [Epoch 1] [Batch 42] Loss: 0.04016
# [Epoch 1] [Batch 43] Loss: 0.04259
# [Epoch 1] [Batch 44] Loss: 0.03898
# [Epoch 1] [Batch 45] Loss: 0.03863
# [Epoch 1] [Batch 46] Loss: 0.04116
# [Epoch 1] [Batch 47] Loss: 0.04009
# [Epoch 1] [Batch 48] Loss: 0.04558
# [Epoch 1] [Batch 49] Loss: 0.03448
# [Epoch 1] [Batch 50] Loss: 0.03803
# [Epoch 1] [Batch 51] Loss: 0.04024
# [Epoch 1] [Batch 52] Loss: 0.05583
# [Epoch 1] [Batch 53] Loss: 0.03624
# [Epoch 1] [Batch 54] Loss: 0.03521
# [Epoch 1] [Batch 55] Loss: 0.04249
# [Epoch 1] [Batch 56] Loss: 0.03497
# [Epoch 1] [Batch 57] Loss: 0.03522
# [Epoch 1] [Batch 58] Loss: 0.04861
# [Epoch 1] [Batch 59] Loss: 0.03872
# [Epoch 1] [Batch 60] Loss: 0.03726
# [Epoch 1] [Batch 61] Loss: 0.05153
# [Epoch 1] [Batch 62] Loss: 0.03009
# [Epoch 1] [Batch 63] Loss: 0.03412
# [Epoch 1] [Batch 64] Loss: 0.03314
# [Epoch 1] [Batch 65] Loss: 0.03107
# [Epoch 1] [Batch 66] Loss: 0.03577
# [Epoch 1] [Batch 67] Loss: 0.03042
# [Epoch 1] [Batch 68] Loss: 0.02664
# [Epoch 1] [Batch 69] Loss: 0.02478
# [Epoch 1] [Batch 70] Loss: 0.03154
# [Epoch 1] [Batch 71] Loss: 0.02574
# [Epoch 1] [Batch 72] Loss: 0.02810
# [Epoch 1] [Batch 73] Loss: 0.02126
# [Epoch 1] [Batch 74] Loss: 0.02172
# [Epoch 1] [Batch 75] Loss: 0.03662
# [Epoch 1] [Batch 76] Loss: 0.03698
# [Epoch 1] [Batch 77] Loss: 0.03755
# [Epoch 1] [Batch 78] Loss: 0.02554
# [Epoch 2] [Batch 0] Loss: 0.03498
# [Epoch 2] [Batch 1] Loss: 0.03482
# [Epoch 2] [Batch 2] Loss: 0.03610
# [Epoch 2] [Batch 3] Loss: 0.03961
# [Epoch 2] [Batch 4] Loss: 0.03693
# [Epoch 2] [Batch 5] Loss: 0.03231
# [Epoch 2] [Batch 6] Loss: 0.03088
# [Epoch 2] [Batch 7] Loss: 0.03479
# [Epoch 2] [Batch 8] Loss: 0.02699
# [Epoch 2] [Batch 9] Loss: 0.03980
# [Epoch 2] [Batch 10] Loss: 0.03210
# [Epoch 2] [Batch 11] Loss: 0.03526
# [Epoch 2] [Batch 12] Loss: 0.03020
# [Epoch 2] [Batch 13] Loss: 0.03154
# [Epoch 2] [Batch 14] Loss: 0.02689
# [Epoch 2] [Batch 15] Loss: 0.02844
# [Epoch 2] [Batch 16] Loss: 0.03098
# [Epoch 2] [Batch 17] Loss: 0.02867
# [Epoch 2] [Batch 18] Loss: 0.02822
# [Epoch 2] [Batch 19] Loss: 0.02018
# [Epoch 2] [Batch 20] Loss: 0.02500
# [Epoch 2] [Batch 21] Loss: 0.02824
# [Epoch 2] [Batch 22] Loss: 0.02503
# [Epoch 2] [Batch 23] Loss: 0.01993
# [Epoch 2] [Batch 24] Loss: 0.02404
# [Epoch 2] [Batch 25] Loss: 0.02075
# [Epoch 2] [Batch 26] Loss: 0.02039
# [Epoch 2] [Batch 27] Loss: 0.02603
# [Epoch 2] [Batch 28] Loss: 0.01854
# [Epoch 2] [Batch 29] Loss: 0.03487
# [Epoch 2] [Batch 30] Loss: 0.02602
# [Epoch 2] [Batch 31] Loss: 0.02230
# [Epoch 2] [Batch 32] Loss: 0.02339
# [Epoch 2] [Batch 33] Loss: 0.02063
# [Epoch 2] [Batch 34] Loss: 0.02218
# [Epoch 2] [Batch 35] Loss: 0.02236
# [Epoch 2] [Batch 36] Loss: 0.01725
# [Epoch 2] [Batch 37] Loss: 0.02100
# [Epoch 2] [Batch 38] Loss: 0.02048
# [Epoch 2] [Batch 39] Loss: 0.01352
# [Epoch 2] [Batch 40] Loss: 0.01738
# [Epoch 2] [Batch 41] Loss: 0.00973
# [Epoch 2] [Batch 42] Loss: 0.00657
# [Epoch 2] [Batch 43] Loss: 0.01039
# [Epoch 2] [Batch 44] Loss: 0.01148
# [Epoch 2] [Batch 45] Loss: 0.01276
# [Epoch 2] [Batch 46] Loss: 0.01393
# [Epoch 2] [Batch 47] Loss: 0.01745
# [Epoch 2] [Batch 48] Loss: 0.01354
# [Epoch 2] [Batch 49] Loss: 0.00591
# [Epoch 2] [Batch 50] Loss: 0.01317
# [Epoch 2] [Batch 51] Loss: 0.02853
# [Epoch 2] [Batch 52] Loss: 0.01880
# [Epoch 2] [Batch 53] Loss: 0.01109
# [Epoch 2] [Batch 54] Loss: 0.00591
# [Epoch 2] [Batch 55] Loss: 0.01235
# [Epoch 2] [Batch 56] Loss: 0.01646
# [Epoch 2] [Batch 57] Loss: 0.00557
# [Epoch 2] [Batch 58] Loss: 0.01639
# [Epoch 2] [Batch 59] Loss: 0.01306
# [Epoch 2] [Batch 60] Loss: 0.01064
# [Epoch 2] [Batch 61] Loss: 0.02207
# [Epoch 2] [Batch 62] Loss: 0.00649
# [Epoch 2] [Batch 63] Loss: 0.00784
# [Epoch 2] [Batch 64] Loss: 0.00812
# [Epoch 2] [Batch 65] Loss: 0.01147
# [Epoch 2] [Batch 66] Loss: 0.00399
# [Epoch 2] [Batch 67] Loss: 0.00327
# [Epoch 2] [Batch 68] Loss: 0.00670
# [Epoch 2] [Batch 69] Loss: 0.00821
# [Epoch 2] [Batch 70] Loss: 0.01716
# [Epoch 2] [Batch 71] Loss: 0.00646
# [Epoch 2] [Batch 72] Loss: 0.00745
# [Epoch 2] [Batch 73] Loss: 0.00539
# [Epoch 2] [Batch 74] Loss: 0.00379
# [Epoch 2] [Batch 75] Loss: 0.02067
# [Epoch 2] [Batch 76] Loss: 0.01970
# [Epoch 2] [Batch 77] Loss: 0.02150
# [Epoch 2] [Batch 78] Loss: 0.00541
# [Epoch 3] [Batch 0] Loss: 0.01373
# [Epoch 3] [Batch 1] Loss: 0.01586
# [Epoch 3] [Batch 2] Loss: 0.01690
# [Epoch 3] [Batch 3] Loss: 0.02098
# [Epoch 3] [Batch 4] Loss: 0.02202
# [Epoch 3] [Batch 5] Loss: 0.01250
# [Epoch 3] [Batch 6] Loss: 0.01591
# [Epoch 3] [Batch 7] Loss: 0.02075
# [Epoch 3] [Batch 8] Loss: 0.01216
# [Epoch 3] [Batch 9] Loss: 0.02406
# [Epoch 3] [Batch 10] Loss: 0.01871
# [Epoch 3] [Batch 11] Loss: 0.02040
# [Epoch 3] [Batch 12] Loss: 0.01376
# [Epoch 3] [Batch 13] Loss: 0.01790
# [Epoch 3] [Batch 14] Loss: 0.01580
# [Epoch 3] [Batch 15] Loss: 0.01720
# [Epoch 3] [Batch 16] Loss: 0.01903
# [Epoch 3] [Batch 17] Loss: 0.01389
# [Epoch 3] [Batch 18] Loss: 0.01749
# [Epoch 3] [Batch 19] Loss: 0.01199
# [Epoch 3] [Batch 20] Loss: 0.01269
# [Epoch 3] [Batch 21] Loss: 0.01437
# [Epoch 3] [Batch 22] Loss: 0.01153
# [Epoch 3] [Batch 23] Loss: 0.01160
# [Epoch 3] [Batch 24] Loss: 0.01273
# [Epoch 3] [Batch 25] Loss: 0.00992
# [Epoch 3] [Batch 26] Loss: 0.00985
# [Epoch 3] [Batch 27] Loss: 0.01405
# [Epoch 3] [Batch 28] Loss: 0.01094
# [Epoch 3] [Batch 29] Loss: 0.01813
# [Epoch 3] [Batch 30] Loss: 0.01237
# [Epoch 3] [Batch 31] Loss: 0.01203
# [Epoch 3] [Batch 32] Loss: 0.01339
# [Epoch 3] [Batch 33] Loss: 0.01133
# [Epoch 3] [Batch 34] Loss: 0.01088
# [Epoch 3] [Batch 35] Loss: 0.01041
# [Epoch 3] [Batch 36] Loss: 0.00773
# [Epoch 3] [Batch 37] Loss: 0.01141
# [Epoch 3] [Batch 38] Loss: 0.01128
# [Epoch 3] [Batch 39] Loss: 0.00805
# [Epoch 3] [Batch 40] Loss: 0.00728
# [Epoch 3] [Batch 41] Loss: 0.00463
# [Epoch 3] [Batch 42] Loss: 0.00347
# [Epoch 3] [Batch 43] Loss: 0.00383
# [Epoch 3] [Batch 44] Loss: 0.00740
# [Epoch 3] [Batch 45] Loss: 0.00891
# [Epoch 3] [Batch 46] Loss: 0.01278
# [Epoch 3] [Batch 47] Loss: 0.01279
# [Epoch 3] [Batch 48] Loss: 0.00755
# [Epoch 3] [Batch 49] Loss: 0.00237
# [Epoch 3] [Batch 50] Loss: 0.00654
# [Epoch 3] [Batch 51] Loss: 0.01512
# [Epoch 3] [Batch 52] Loss: 0.01644
# [Epoch 3] [Batch 53] Loss: 0.00593
# [Epoch 3] [Batch 54] Loss: 0.00240
# [Epoch 3] [Batch 55] Loss: 0.01126
# [Epoch 3] [Batch 56] Loss: 0.00568
# [Epoch 3] [Batch 57] Loss: 0.00653
# [Epoch 3] [Batch 58] Loss: 0.00725
# [Epoch 3] [Batch 59] Loss: 0.00386
# [Epoch 3] [Batch 60] Loss: 0.00505
# [Epoch 3] [Batch 61] Loss: 0.02267
# [Epoch 3] [Batch 62] Loss: 0.00448
# [Epoch 3] [Batch 63] Loss: 0.01000
# [Epoch 3] [Batch 64] Loss: 0.01288
# [Epoch 3] [Batch 65] Loss: 0.00885
# [Epoch 3] [Batch 66] Loss: 0.01068
# [Epoch 3] [Batch 67] Loss: 0.00049
# [Epoch 3] [Batch 68] Loss: 0.00533
# [Epoch 3] [Batch 69] Loss: 0.00709
# [Epoch 3] [Batch 70] Loss: 0.01065
# [Epoch 3] [Batch 71] Loss: 0.00569
# [Epoch 3] [Batch 72] Loss: 0.00416
# [Epoch 3] [Batch 73] Loss: 0.00759
# [Epoch 3] [Batch 74] Loss: 0.00152
# [Epoch 3] [Batch 75] Loss: 0.01404
# [Epoch 3] [Batch 76] Loss: 0.01273
# [Epoch 3] [Batch 77] Loss: 0.01329
# [Epoch 3] [Batch 78] Loss: 0.00048
# [Epoch 4] [Batch 0] Loss: 0.00989
# [Epoch 4] [Batch 1] Loss: 0.00935
# [Epoch 4] [Batch 2] Loss: 0.01288
# [Epoch 4] [Batch 3] Loss: 0.01182
# [Epoch 4] [Batch 4] Loss: 0.01145
# [Epoch 4] [Batch 5] Loss: 0.00825
# [Epoch 4] [Batch 6] Loss: 0.00913
# [Epoch 4] [Batch 7] Loss: 0.01484
# [Epoch 4] [Batch 8] Loss: 0.01195
# [Epoch 4] [Batch 9] Loss: 0.01866
# [Epoch 4] [Batch 10] Loss: 0.01165
# [Epoch 4] [Batch 11] Loss: 0.01103
# [Epoch 4] [Batch 12] Loss: 0.00743
# [Epoch 4] [Batch 13] Loss: 0.01353
# [Epoch 4] [Batch 14] Loss: 0.00857
# [Epoch 4] [Batch 15] Loss: 0.01015
# [Epoch 4] [Batch 16] Loss: 0.01213
# [Epoch 4] [Batch 17] Loss: 0.01131
# [Epoch 4] [Batch 18] Loss: 0.01163
# [Epoch 4] [Batch 19] Loss: 0.00765
# [Epoch 4] [Batch 20] Loss: 0.00774
# [Epoch 4] [Batch 21] Loss: 0.00976
# [Epoch 4] [Batch 22] Loss: 0.00669
# [Epoch 4] [Batch 23] Loss: 0.00844
# [Epoch 4] [Batch 24] Loss: 0.00888
# [Epoch 4] [Batch 25] Loss: 0.00779
# [Epoch 4] [Batch 26] Loss: 0.00615
# [Epoch 4] [Batch 27] Loss: 0.00971
# [Epoch 4] [Batch 28] Loss: 0.00843
# [Epoch 4] [Batch 29] Loss: 0.01233
# [Epoch 4] [Batch 30] Loss: 0.00901
# [Epoch 4] [Batch 31] Loss: 0.00705
# [Epoch 4] [Batch 32] Loss: 0.01023
# [Epoch 4] [Batch 33] Loss: 0.00842
# [Epoch 4] [Batch 34] Loss: 0.00777
# [Epoch 4] [Batch 35] Loss: 0.00735
# [Epoch 4] [Batch 36] Loss: 0.00604
# [Epoch 4] [Batch 37] Loss: 0.00963
# [Epoch 4] [Batch 38] Loss: 0.00863
# [Epoch 4] [Batch 39] Loss: 0.00584
# [Epoch 4] [Batch 40] Loss: 0.00368
# [Epoch 4] [Batch 41] Loss: 0.00365
# [Epoch 4] [Batch 42] Loss: 0.00198
# [Epoch 4] [Batch 43] Loss: 0.00210
# [Epoch 4] [Batch 44] Loss: 0.00566
# [Epoch 4] [Batch 45] Loss: 0.00745
# [Epoch 4] [Batch 46] Loss: 0.01069
# [Epoch 4] [Batch 47] Loss: 0.01075
# [Epoch 4] [Batch 48] Loss: 0.00674
# [Epoch 4] [Batch 49] Loss: 0.00084
# [Epoch 4] [Batch 50] Loss: 0.00576
# [Epoch 4] [Batch 51] Loss: 0.00870
# [Epoch 4] [Batch 52] Loss: 0.00899
# [Epoch 4] [Batch 53] Loss: 0.00274
# [Epoch 4] [Batch 54] Loss: 0.00101
# [Epoch 4] [Batch 55] Loss: 0.00293
# [Epoch 4] [Batch 56] Loss: 0.00335
# [Epoch 4] [Batch 57] Loss: 0.00045
# [Epoch 4] [Batch 58] Loss: 0.00422
# [Epoch 4] [Batch 59] Loss: 0.00220
# [Epoch 4] [Batch 60] Loss: 0.00243
# [Epoch 4] [Batch 61] Loss: 0.01712
# [Epoch 4] [Batch 62] Loss: 0.00135
# [Epoch 4] [Batch 63] Loss: 0.00323
# [Epoch 4] [Batch 64] Loss: 0.00117
# [Epoch 4] [Batch 65] Loss: 0.00398
# [Epoch 4] [Batch 66] Loss: 0.00398
# [Epoch 4] [Batch 67] Loss: 0.00030
# [Epoch 4] [Batch 68] Loss: 0.00194
# [Epoch 4] [Batch 69] Loss: 0.00484
# [Epoch 4] [Batch 70] Loss: 0.00454
# [Epoch 4] [Batch 71] Loss: 0.00206
# [Epoch 4] [Batch 72] Loss: 0.00534
# [Epoch 4] [Batch 73] Loss: 0.00107
# [Epoch 4] [Batch 74] Loss: 0.00140
# [Epoch 4] [Batch 75] Loss: 0.01128
# [Epoch 4] [Batch 76] Loss: 0.01197
# [Epoch 4] [Batch 77] Loss: 0.01403
# [Epoch 4] [Batch 78] Loss: 0.00075
# [Epoch 5] [Batch 0] Loss: 0.00711
# [Epoch 5] [Batch 1] Loss: 0.00537
# [Epoch 5] [Batch 2] Loss: 0.00591
# [Epoch 5] [Batch 3] Loss: 0.00552
# [Epoch 5] [Batch 4] Loss: 0.00699
# [Epoch 5] [Batch 5] Loss: 0.00447
# [Epoch 5] [Batch 6] Loss: 0.00978
# [Epoch 5] [Batch 7] Loss: 0.00670
# [Epoch 5] [Batch 8] Loss: 0.00859
# [Epoch 5] [Batch 9] Loss: 0.01545
# [Epoch 5] [Batch 10] Loss: 0.01002
# [Epoch 5] [Batch 11] Loss: 0.00765
# [Epoch 5] [Batch 12] Loss: 0.00581
# [Epoch 5] [Batch 13] Loss: 0.01049
# [Epoch 5] [Batch 14] Loss: 0.00545
# [Epoch 5] [Batch 15] Loss: 0.00715
# [Epoch 5] [Batch 16] Loss: 0.01177
# [Epoch 5] [Batch 17] Loss: 0.00898
# [Epoch 5] [Batch 18] Loss: 0.01063
# [Epoch 5] [Batch 19] Loss: 0.00460
# [Epoch 5] [Batch 20] Loss: 0.00599
# [Epoch 5] [Batch 21] Loss: 0.00786
# [Epoch 5] [Batch 22] Loss: 0.00459
# [Epoch 5] [Batch 23] Loss: 0.00799
# [Epoch 5] [Batch 24] Loss: 0.00568
# [Epoch 5] [Batch 25] Loss: 0.00712
# [Epoch 5] [Batch 26] Loss: 0.00510
# [Epoch 5] [Batch 27] Loss: 0.00598
# [Epoch 5] [Batch 28] Loss: 0.00664
# [Epoch 5] [Batch 29] Loss: 0.01082
# [Epoch 5] [Batch 30] Loss: 0.00756
# [Epoch 5] [Batch 31] Loss: 0.00679
# [Epoch 5] [Batch 32] Loss: 0.00735
# [Epoch 5] [Batch 33] Loss: 0.00674
# [Epoch 5] [Batch 34] Loss: 0.00592
# [Epoch 5] [Batch 35] Loss: 0.00659
# [Epoch 5] [Batch 36] Loss: 0.00586
# [Epoch 5] [Batch 37] Loss: 0.00897
# [Epoch 5] [Batch 38] Loss: 0.00688
# [Epoch 5] [Batch 39] Loss: 0.00471
# [Epoch 5] [Batch 40] Loss: 0.00399
# [Epoch 5] [Batch 41] Loss: 0.00329
# [Epoch 5] [Batch 42] Loss: 0.00064
# [Epoch 5] [Batch 43] Loss: 0.00090
# [Epoch 5] [Batch 44] Loss: 0.00357
# [Epoch 5] [Batch 45] Loss: 0.00418
# [Epoch 5] [Batch 46] Loss: 0.00899
# [Epoch 5] [Batch 47] Loss: 0.00955
# [Epoch 5] [Batch 48] Loss: 0.00589
# [Epoch 5] [Batch 49] Loss: 0.00011
# [Epoch 5] [Batch 50] Loss: 0.00321
# [Epoch 5] [Batch 51] Loss: 0.00647
# [Epoch 5] [Batch 52] Loss: 0.00442
# [Epoch 5] [Batch 53] Loss: 0.00211
# [Epoch 5] [Batch 54] Loss: 0.00074
# [Epoch 5] [Batch 55] Loss: 0.00164
# [Epoch 5] [Batch 56] Loss: 0.00334
# [Epoch 5] [Batch 57] Loss: 0.00095
# [Epoch 5] [Batch 58] Loss: 0.00323
# [Epoch 5] [Batch 59] Loss: 0.00184
# [Epoch 5] [Batch 60] Loss: 0.00054
# [Epoch 5] [Batch 61] Loss: 0.01017
# [Epoch 5] [Batch 62] Loss: 0.00088
# [Epoch 5] [Batch 63] Loss: 0.00192
# [Epoch 5] [Batch 64] Loss: 0.00043
# [Epoch 5] [Batch 65] Loss: 0.00268
# [Epoch 5] [Batch 66] Loss: 0.00220
# [Epoch 5] [Batch 67] Loss: 0.00041
# [Epoch 5] [Batch 68] Loss: 0.00218
# [Epoch 5] [Batch 69] Loss: 0.00308
# [Epoch 5] [Batch 70] Loss: 0.00294
# [Epoch 5] [Batch 71] Loss: 0.00090
# [Epoch 5] [Batch 72] Loss: 0.00345
# [Epoch 5] [Batch 73] Loss: 0.00064
# [Epoch 5] [Batch 74] Loss: 0.00246
# [Epoch 5] [Batch 75] Loss: 0.01166
# [Epoch 5] [Batch 76] Loss: 0.00953
# [Epoch 5] [Batch 77] Loss: 0.01056
# [Epoch 5] [Batch 78] Loss: 0.00009
# [Epoch 6] [Batch 0] Loss: 0.00763
# [Epoch 6] [Batch 1] Loss: 0.00503
# [Epoch 6] [Batch 2] Loss: 0.00597
# [Epoch 6] [Batch 3] Loss: 0.00417
# [Epoch 6] [Batch 4] Loss: 0.00727
# [Epoch 6] [Batch 5] Loss: 0.00391
# [Epoch 6] [Batch 6] Loss: 0.00636
# [Epoch 6] [Batch 7] Loss: 0.00566
# [Epoch 6] [Batch 8] Loss: 0.00913
# [Epoch 6] [Batch 9] Loss: 0.01246
# [Epoch 6] [Batch 10] Loss: 0.00915
# [Epoch 6] [Batch 11] Loss: 0.00838
# [Epoch 6] [Batch 12] Loss: 0.00491
# [Epoch 6] [Batch 13] Loss: 0.00899
# [Epoch 6] [Batch 14] Loss: 0.00497
# [Epoch 6] [Batch 15] Loss: 0.00545
# [Epoch 6] [Batch 16] Loss: 0.01050
# [Epoch 6] [Batch 17] Loss: 0.00859
# [Epoch 6] [Batch 18] Loss: 0.00929
# [Epoch 6] [Batch 19] Loss: 0.00486
# [Epoch 6] [Batch 20] Loss: 0.00526
# [Epoch 6] [Batch 21] Loss: 0.00703
# [Epoch 6] [Batch 22] Loss: 0.00503
# [Epoch 6] [Batch 23] Loss: 0.00677
# [Epoch 6] [Batch 24] Loss: 0.00411
# [Epoch 6] [Batch 25] Loss: 0.00673
# [Epoch 6] [Batch 26] Loss: 0.00533
# [Epoch 6] [Batch 27] Loss: 0.00628
# [Epoch 6] [Batch 28] Loss: 0.00586
# [Epoch 6] [Batch 29] Loss: 0.01035
# [Epoch 6] [Batch 30] Loss: 0.00638
# [Epoch 6] [Batch 31] Loss: 0.00745
# [Epoch 6] [Batch 32] Loss: 0.00645
# [Epoch 6] [Batch 33] Loss: 0.00748
# [Epoch 6] [Batch 34] Loss: 0.00662
# [Epoch 6] [Batch 35] Loss: 0.00640
# [Epoch 6] [Batch 36] Loss: 0.00436
# [Epoch 6] [Batch 37] Loss: 0.00766
# [Epoch 6] [Batch 38] Loss: 0.00506
# [Epoch 6] [Batch 39] Loss: 0.00337
# [Epoch 6] [Batch 40] Loss: 0.00333
# [Epoch 6] [Batch 41] Loss: 0.00261
# [Epoch 6] [Batch 42] Loss: 0.00083
# [Epoch 6] [Batch 43] Loss: 0.00046
# [Epoch 6] [Batch 44] Loss: 0.00227
# [Epoch 6] [Batch 45] Loss: 0.00343
# [Epoch 6] [Batch 46] Loss: 0.00814
# [Epoch 6] [Batch 47] Loss: 0.00914
# [Epoch 6] [Batch 48] Loss: 0.00573
# [Epoch 6] [Batch 49] Loss: 0.00013
# [Epoch 6] [Batch 50] Loss: 0.00186
# [Epoch 6] [Batch 51] Loss: 0.00713
# [Epoch 6] [Batch 52] Loss: 0.00292
# [Epoch 6] [Batch 53] Loss: 0.00215
# [Epoch 6] [Batch 54] Loss: 0.00020
# [Epoch 6] [Batch 55] Loss: 0.00090
# [Epoch 6] [Batch 56] Loss: 0.00224
# [Epoch 6] [Batch 57] Loss: 0.00117
# [Epoch 6] [Batch 58] Loss: 0.00168
# [Epoch 6] [Batch 59] Loss: 0.00213
# [Epoch 6] [Batch 60] Loss: 0.00045
# [Epoch 6] [Batch 61] Loss: 0.00707
# [Epoch 6] [Batch 62] Loss: 0.00064
# [Epoch 6] [Batch 63] Loss: 0.00171
# [Epoch 6] [Batch 64] Loss: 0.00053
# [Epoch 6] [Batch 65] Loss: 0.00272
# [Epoch 6] [Batch 66] Loss: 0.00122
# [Epoch 6] [Batch 67] Loss: 0.00018
# [Epoch 6] [Batch 68] Loss: 0.00186
# [Epoch 6] [Batch 69] Loss: 0.00304
# [Epoch 6] [Batch 70] Loss: 0.00021
# [Epoch 6] [Batch 71] Loss: 0.00218
# [Epoch 6] [Batch 72] Loss: 0.00473
# [Epoch 6] [Batch 73] Loss: 0.00038
# [Epoch 6] [Batch 74] Loss: 0.00128
# [Epoch 6] [Batch 75] Loss: 0.00866
# [Epoch 6] [Batch 76] Loss: 0.00816
# [Epoch 6] [Batch 77] Loss: 0.00852
# [Epoch 6] [Batch 78] Loss: 0.00001
# [Epoch 7] [Batch 0] Loss: 0.00448
# [Epoch 7] [Batch 1] Loss: 0.00388
# [Epoch 7] [Batch 2] Loss: 0.00426
# [Epoch 7] [Batch 3] Loss: 0.00436
# [Epoch 7] [Batch 4] Loss: 0.00719
# [Epoch 7] [Batch 5] Loss: 0.00313
# [Epoch 7] [Batch 6] Loss: 0.00230
# [Epoch 7] [Batch 7] Loss: 0.00538
# [Epoch 7] [Batch 8] Loss: 0.00952
# [Epoch 7] [Batch 9] Loss: 0.01104
# [Epoch 7] [Batch 10] Loss: 0.00934
# [Epoch 7] [Batch 11] Loss: 0.00926
# [Epoch 7] [Batch 12] Loss: 0.00480
# [Epoch 7] [Batch 13] Loss: 0.00989
# [Epoch 7] [Batch 14] Loss: 0.00330
# [Epoch 7] [Batch 15] Loss: 0.00411
# [Epoch 7] [Batch 16] Loss: 0.00848
# [Epoch 7] [Batch 17] Loss: 0.00749
# [Epoch 7] [Batch 18] Loss: 0.00687
# [Epoch 7] [Batch 19] Loss: 0.00476
# [Epoch 7] [Batch 20] Loss: 0.00442
# [Epoch 7] [Batch 21] Loss: 0.00501
# [Epoch 7] [Batch 22] Loss: 0.00611
# [Epoch 7] [Batch 23] Loss: 0.00627
# [Epoch 7] [Batch 24] Loss: 0.00378
# [Epoch 7] [Batch 25] Loss: 0.00420
# [Epoch 7] [Batch 26] Loss: 0.00249
# [Epoch 7] [Batch 27] Loss: 0.00427
# [Epoch 7] [Batch 28] Loss: 0.00496
# [Epoch 7] [Batch 29] Loss: 0.01218
# [Epoch 7] [Batch 30] Loss: 0.00427
# [Epoch 7] [Batch 31] Loss: 0.00773
# [Epoch 7] [Batch 32] Loss: 0.00583
# [Epoch 7] [Batch 33] Loss: 0.00766
# [Epoch 7] [Batch 34] Loss: 0.00534
# [Epoch 7] [Batch 35] Loss: 0.00626
# [Epoch 7] [Batch 36] Loss: 0.00418
# [Epoch 7] [Batch 37] Loss: 0.00602
# [Epoch 7] [Batch 38] Loss: 0.00493
# [Epoch 7] [Batch 39] Loss: 0.00200
# [Epoch 7] [Batch 40] Loss: 0.00404
# [Epoch 7] [Batch 41] Loss: 0.00160
# [Epoch 7] [Batch 42] Loss: 0.00077
# [Epoch 7] [Batch 43] Loss: 0.00019
# [Epoch 7] [Batch 44] Loss: 0.00172
# [Epoch 7] [Batch 45] Loss: 0.00425
# [Epoch 7] [Batch 46] Loss: 0.00666
# [Epoch 7] [Batch 47] Loss: 0.00881
# [Epoch 7] [Batch 48] Loss: 0.00598
# [Epoch 7] [Batch 49] Loss: 0.00017
# [Epoch 7] [Batch 50] Loss: 0.00177
# [Epoch 7] [Batch 51] Loss: 0.00554
# [Epoch 7] [Batch 52] Loss: 0.00359
# [Epoch 7] [Batch 53] Loss: 0.00142
# [Epoch 7] [Batch 54] Loss: 0.00030
# [Epoch 7] [Batch 55] Loss: 0.00105
# [Epoch 7] [Batch 56] Loss: 0.00203
# [Epoch 7] [Batch 57] Loss: 0.00037
# [Epoch 7] [Batch 58] Loss: 0.00220
# [Epoch 7] [Batch 59] Loss: 0.00177
# [Epoch 7] [Batch 60] Loss: 0.00022
# [Epoch 7] [Batch 61] Loss: 0.00623
# [Epoch 7] [Batch 62] Loss: 0.00025
# [Epoch 7] [Batch 63] Loss: 0.00185
# [Epoch 7] [Batch 64] Loss: 0.00063
# [Epoch 7] [Batch 65] Loss: 0.00334
# [Epoch 7] [Batch 66] Loss: 0.00089
# [Epoch 7] [Batch 67] Loss: 0.00002
# [Epoch 7] [Batch 68] Loss: 0.00024
# [Epoch 7] [Batch 69] Loss: 0.00063
# [Epoch 7] [Batch 70] Loss: 0.00041
# [Epoch 7] [Batch 71] Loss: 0.00105
# [Epoch 7] [Batch 72] Loss: 0.00246
# [Epoch 7] [Batch 73] Loss: 0.00032
# [Epoch 7] [Batch 74] Loss: 0.00093
# [Epoch 7] [Batch 75] Loss: 0.00900
# [Epoch 7] [Batch 76] Loss: 0.00642
# [Epoch 7] [Batch 77] Loss: 0.00580
# [Epoch 7] [Batch 78] Loss: 0.00000
# [Epoch 8] [Batch 0] Loss: 0.00222
# [Epoch 8] [Batch 1] Loss: 0.00326
# [Epoch 8] [Batch 2] Loss: 0.00277
# [Epoch 8] [Batch 3] Loss: 0.00325
# [Epoch 8] [Batch 4] Loss: 0.00615
# [Epoch 8] [Batch 5] Loss: 0.00395
# [Epoch 8] [Batch 6] Loss: 0.00191
# [Epoch 8] [Batch 7] Loss: 0.00764
# [Epoch 8] [Batch 8] Loss: 0.00800
# [Epoch 8] [Batch 9] Loss: 0.00844
# [Epoch 8] [Batch 10] Loss: 0.00762
# [Epoch 8] [Batch 11] Loss: 0.00646
# [Epoch 8] [Batch 12] Loss: 0.00419
# [Epoch 8] [Batch 13] Loss: 0.00727
# [Epoch 8] [Batch 14] Loss: 0.00262
# [Epoch 8] [Batch 15] Loss: 0.00370
# [Epoch 8] [Batch 16] Loss: 0.00771
# [Epoch 8] [Batch 17] Loss: 0.00636
# [Epoch 8] [Batch 18] Loss: 0.00500
# [Epoch 8] [Batch 19] Loss: 0.00323
# [Epoch 8] [Batch 20] Loss: 0.00268
# [Epoch 8] [Batch 21] Loss: 0.00315
# [Epoch 8] [Batch 22] Loss: 0.00367
# [Epoch 8] [Batch 23] Loss: 0.00348
# [Epoch 8] [Batch 24] Loss: 0.00455
# [Epoch 8] [Batch 25] Loss: 0.00340
# [Epoch 8] [Batch 26] Loss: 0.00360
# [Epoch 8] [Batch 27] Loss: 0.00524
# [Epoch 8] [Batch 28] Loss: 0.00384
# [Epoch 8] [Batch 29] Loss: 0.00737
# [Epoch 8] [Batch 30] Loss: 0.00290
# [Epoch 8] [Batch 31] Loss: 0.00637
# [Epoch 8] [Batch 32] Loss: 0.00378
# [Epoch 8] [Batch 33] Loss: 0.00551
# [Epoch 8] [Batch 34] Loss: 0.00256
# [Epoch 8] [Batch 35] Loss: 0.00468
# [Epoch 8] [Batch 36] Loss: 0.00202
# [Epoch 8] [Batch 37] Loss: 0.00589
# [Epoch 8] [Batch 38] Loss: 0.00363
# [Epoch 8] [Batch 39] Loss: 0.00264
# [Epoch 8] [Batch 40] Loss: 0.00102
# [Epoch 8] [Batch 41] Loss: 0.00179
# [Epoch 8] [Batch 42] Loss: 0.00012
# [Epoch 8] [Batch 43] Loss: 0.00058
# [Epoch 8] [Batch 44] Loss: 0.00082
# [Epoch 8] [Batch 45] Loss: 0.00276
# [Epoch 8] [Batch 46] Loss: 0.00972
# [Epoch 8] [Batch 47] Loss: 0.00826
# [Epoch 8] [Batch 48] Loss: 0.00485
# [Epoch 8] [Batch 49] Loss: 0.00003
# [Epoch 8] [Batch 50] Loss: 0.00336
# [Epoch 8] [Batch 51] Loss: 0.00914
# [Epoch 8] [Batch 52] Loss: 0.00241
# [Epoch 8] [Batch 53] Loss: 0.00095
# [Epoch 8] [Batch 54] Loss: 0.00032
# [Epoch 8] [Batch 55] Loss: 0.00089
# [Epoch 8] [Batch 56] Loss: 0.00222
# [Epoch 8] [Batch 57] Loss: 0.00014
# [Epoch 8] [Batch 58] Loss: 0.00184
# [Epoch 8] [Batch 59] Loss: 0.00075
# [Epoch 8] [Batch 60] Loss: 0.00128
# [Epoch 8] [Batch 61] Loss: 0.00261
# [Epoch 8] [Batch 62] Loss: 0.00025
# [Epoch 8] [Batch 63] Loss: 0.00160
# [Epoch 8] [Batch 64] Loss: 0.00022
# [Epoch 8] [Batch 65] Loss: 0.00175
# [Epoch 8] [Batch 66] Loss: 0.00130
# [Epoch 8] [Batch 67] Loss: 0.00026
# [Epoch 8] [Batch 68] Loss: 0.00042
# [Epoch 8] [Batch 69] Loss: 0.00077
# [Epoch 8] [Batch 70] Loss: 0.00109
# [Epoch 8] [Batch 71] Loss: 0.00007
# [Epoch 8] [Batch 72] Loss: 0.00062
# [Epoch 8] [Batch 73] Loss: 0.00024
# [Epoch 8] [Batch 74] Loss: 0.00177
# [Epoch 8] [Batch 75] Loss: 0.00715
# [Epoch 8] [Batch 76] Loss: 0.00814
# [Epoch 8] [Batch 77] Loss: 0.00533
# [Epoch 8] [Batch 78] Loss: 0.00000
# [Epoch 9] [Batch 0] Loss: 0.00158
# [Epoch 9] [Batch 1] Loss: 0.00349
# [Epoch 9] [Batch 2] Loss: 0.00202
# [Epoch 9] [Batch 3] Loss: 0.00309
# [Epoch 9] [Batch 4] Loss: 0.00430
# [Epoch 9] [Batch 5] Loss: 0.00288
# [Epoch 9] [Batch 6] Loss: 0.00096
# [Epoch 9] [Batch 7] Loss: 0.00606
# [Epoch 9] [Batch 8] Loss: 0.00760
# [Epoch 9] [Batch 9] Loss: 0.00790
# [Epoch 9] [Batch 10] Loss: 0.00483
# [Epoch 9] [Batch 11] Loss: 0.00521
# [Epoch 9] [Batch 12] Loss: 0.00218
# [Epoch 9] [Batch 13] Loss: 0.00480
# [Epoch 9] [Batch 14] Loss: 0.00173
# [Epoch 9] [Batch 15] Loss: 0.00101
# [Epoch 9] [Batch 16] Loss: 0.00694
# [Epoch 9] [Batch 17] Loss: 0.00557
# [Epoch 9] [Batch 18] Loss: 0.00559
# [Epoch 9] [Batch 19] Loss: 0.00267
# [Epoch 9] [Batch 20] Loss: 0.00317
# [Epoch 9] [Batch 21] Loss: 0.00195
# [Epoch 9] [Batch 22] Loss: 0.00376
# [Epoch 9] [Batch 23] Loss: 0.00321
# [Epoch 9] [Batch 24] Loss: 0.00416
# [Epoch 9] [Batch 25] Loss: 0.00349
# [Epoch 9] [Batch 26] Loss: 0.00245
# [Epoch 9] [Batch 27] Loss: 0.00318
# [Epoch 9] [Batch 28] Loss: 0.00252
# [Epoch 9] [Batch 29] Loss: 0.00627
# [Epoch 9] [Batch 30] Loss: 0.00480
# [Epoch 9] [Batch 31] Loss: 0.00489
# [Epoch 9] [Batch 32] Loss: 0.00326
# [Epoch 9] [Batch 33] Loss: 0.00414
# [Epoch 9] [Batch 34] Loss: 0.00228
# [Epoch 9] [Batch 35] Loss: 0.00415
# [Epoch 9] [Batch 36] Loss: 0.00293
# [Epoch 9] [Batch 37] Loss: 0.00534
# [Epoch 9] [Batch 38] Loss: 0.00444
# [Epoch 9] [Batch 39] Loss: 0.00337
# [Epoch 9] [Batch 40] Loss: 0.00102
# [Epoch 9] [Batch 41] Loss: 0.00088
# [Epoch 9] [Batch 42] Loss: 0.00013
# [Epoch 9] [Batch 43] Loss: 0.00013
# [Epoch 9] [Batch 44] Loss: 0.00069
# [Epoch 9] [Batch 45] Loss: 0.00243
# [Epoch 9] [Batch 46] Loss: 0.01037
# [Epoch 9] [Batch 47] Loss: 0.00764
# [Epoch 9] [Batch 48] Loss: 0.00564
# [Epoch 9] [Batch 49] Loss: 0.00004
# [Epoch 9] [Batch 50] Loss: 0.00175
# [Epoch 9] [Batch 51] Loss: 0.00446
# [Epoch 9] [Batch 52] Loss: 0.00212
# [Epoch 9] [Batch 53] Loss: 0.00041
# [Epoch 9] [Batch 54] Loss: 0.00006
# [Epoch 9] [Batch 55] Loss: 0.00155
# [Epoch 9] [Batch 56] Loss: 0.00077
# [Epoch 9] [Batch 57] Loss: 0.00013
# [Epoch 9] [Batch 58] Loss: 0.00161
# [Epoch 9] [Batch 59] Loss: 0.00052
# [Epoch 9] [Batch 60] Loss: 0.00068
# [Epoch 9] [Batch 61] Loss: 0.00200
# [Epoch 9] [Batch 62] Loss: 0.00014
# [Epoch 9] [Batch 63] Loss: 0.00212
# [Epoch 9] [Batch 64] Loss: 0.00096
# [Epoch 9] [Batch 65] Loss: 0.00169
# [Epoch 9] [Batch 66] Loss: 0.00121
# [Epoch 9] [Batch 67] Loss: 0.00025
# [Epoch 9] [Batch 68] Loss: 0.00007
# [Epoch 9] [Batch 69] Loss: 0.00043
# [Epoch 9] [Batch 70] Loss: 0.00176
# [Epoch 9] [Batch 71] Loss: 0.00037
# [Epoch 9] [Batch 72] Loss: 0.00070
# [Epoch 9] [Batch 73] Loss: 0.00015
# [Epoch 9] [Batch 74] Loss: 0.00096
# [Epoch 9] [Batch 75] Loss: 0.00505
# [Epoch 9] [Batch 76] Loss: 0.00681
# [Epoch 9] [Batch 77] Loss: 0.00365
# [Epoch 9] [Batch 78] Loss: 0.00001
# [Epoch 10] [Batch 0] Loss: 0.00095
# [Epoch 10] [Batch 1] Loss: 0.00278
# [Epoch 10] [Batch 2] Loss: 0.00182
# [Epoch 10] [Batch 3] Loss: 0.00267
# [Epoch 10] [Batch 4] Loss: 0.00366
# [Epoch 10] [Batch 5] Loss: 0.00209
# [Epoch 10] [Batch 6] Loss: 0.00085
# [Epoch 10] [Batch 7] Loss: 0.00421
# [Epoch 10] [Batch 8] Loss: 0.00546
# [Epoch 10] [Batch 9] Loss: 0.00736
# [Epoch 10] [Batch 10] Loss: 0.00613
# [Epoch 10] [Batch 11] Loss: 0.00485
# [Epoch 10] [Batch 12] Loss: 0.00287
# [Epoch 10] [Batch 13] Loss: 0.00386
# [Epoch 10] [Batch 14] Loss: 0.00148
# [Epoch 10] [Batch 15] Loss: 0.00141
# [Epoch 10] [Batch 16] Loss: 0.00700
# [Epoch 10] [Batch 17] Loss: 0.00514
# [Epoch 10] [Batch 18] Loss: 0.00429
# [Epoch 10] [Batch 19] Loss: 0.00216
# [Epoch 10] [Batch 20] Loss: 0.00292
# [Epoch 10] [Batch 21] Loss: 0.00186
# [Epoch 10] [Batch 22] Loss: 0.00219
# [Epoch 10] [Batch 23] Loss: 0.00339
# [Epoch 10] [Batch 24] Loss: 0.00377
# [Epoch 10] [Batch 25] Loss: 0.00421
# [Epoch 10] [Batch 26] Loss: 0.00236
# [Epoch 10] [Batch 27] Loss: 0.00277
# [Epoch 10] [Batch 28] Loss: 0.00172
# [Epoch 10] [Batch 29] Loss: 0.00702
# [Epoch 10] [Batch 30] Loss: 0.00381
# [Epoch 10] [Batch 31] Loss: 0.00715
# [Epoch 10] [Batch 32] Loss: 0.00247
# [Epoch 10] [Batch 33] Loss: 0.00434
# [Epoch 10] [Batch 34] Loss: 0.00293
# [Epoch 10] [Batch 35] Loss: 0.00424
# [Epoch 10] [Batch 36] Loss: 0.00276
# [Epoch 10] [Batch 37] Loss: 0.00408
# [Epoch 10] [Batch 38] Loss: 0.00338
# [Epoch 10] [Batch 39] Loss: 0.00227
# [Epoch 10] [Batch 40] Loss: 0.00140
# [Epoch 10] [Batch 41] Loss: 0.00151
# [Epoch 10] [Batch 42] Loss: 0.00027
# [Epoch 10] [Batch 43] Loss: 0.00031
# [Epoch 10] [Batch 44] Loss: 0.00177
# [Epoch 10] [Batch 45] Loss: 0.00180
# [Epoch 10] [Batch 46] Loss: 0.00392
# [Epoch 10] [Batch 47] Loss: 0.00422
# [Epoch 10] [Batch 48] Loss: 0.00458
# [Epoch 10] [Batch 49] Loss: 0.00015
# [Epoch 10] [Batch 50] Loss: 0.00250
# [Epoch 10] [Batch 51] Loss: 0.00890
# [Epoch 10] [Batch 52] Loss: 0.00218
# [Epoch 10] [Batch 53] Loss: 0.00018
# [Epoch 10] [Batch 54] Loss: 0.00003
# [Epoch 10] [Batch 55] Loss: 0.00021
# [Epoch 10] [Batch 56] Loss: 0.00046
# [Epoch 10] [Batch 57] Loss: 0.00001
# [Epoch 10] [Batch 58] Loss: 0.00159
# [Epoch 10] [Batch 59] Loss: 0.00006
# [Epoch 10] [Batch 60] Loss: 0.00002
# [Epoch 10] [Batch 61] Loss: 0.00462
# [Epoch 10] [Batch 62] Loss: 0.00022
# [Epoch 10] [Batch 63] Loss: 0.00191
# [Epoch 10] [Batch 64] Loss: 0.00022
# [Epoch 10] [Batch 65] Loss: 0.00075
# [Epoch 10] [Batch 66] Loss: 0.00120
# [Epoch 10] [Batch 67] Loss: 0.00006
# [Epoch 10] [Batch 68] Loss: 0.00103
# [Epoch 10] [Batch 69] Loss: 0.00134
# [Epoch 10] [Batch 70] Loss: 0.00045
# [Epoch 10] [Batch 71] Loss: 0.00004
# [Epoch 10] [Batch 72] Loss: 0.00049
# [Epoch 10] [Batch 73] Loss: 0.00004
# [Epoch 10] [Batch 74] Loss: 0.00131
# [Epoch 10] [Batch 75] Loss: 0.00508
# [Epoch 10] [Batch 76] Loss: 0.00518
# [Epoch 10] [Batch 77] Loss: 0.00362
# [Epoch 10] [Batch 78] Loss: 0.00001

# %%
for batch_idx, (images, labels) in enumerate(train_loader):
    images = images.to(device).double()
    labels_one_hot = torch.nn.functional.one_hot(labels, 10).to(device).double()
    
    outputs = model(images)
    
    # Get predicted classes
    _, predicted = torch.max(outputs, dim=1)
    
    # Calculate accuracy
    correct = (predicted == labels.to(device)).sum().item()
    total = labels.size(0)
    accuracy = 100 * correct / total
    
    outputs_one_hot = torch.nn.functional.one_hot(predicted, 10).double()
    loss = criterion(outputs_one_hot, labels_one_hot)
    
    if epoch % 1 == 0:
        print(f'[Epoch {epoch + 1}] [Batch {batch_idx}] '
                f'Loss: {loss.item():.5f} | '
                f'Accuracy: {accuracy:.2f}% '
                f'({correct}/{total})')
# Out:
# [Epoch 10] [Batch 0] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 1] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 2] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 3] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 4] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 5] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 6] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 7] Loss: 0.01719 | Accuracy: 91.41% (117/128)
# [Epoch 10] [Batch 8] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 9] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 10] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 11] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 12] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 13] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 14] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 15] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 16] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 17] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 18] Loss: 0.01406 | Accuracy: 92.97% (119/128)
# [Epoch 10] [Batch 19] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 20] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 21] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 22] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 23] Loss: 0.01406 | Accuracy: 92.97% (119/128)
# [Epoch 10] [Batch 24] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 25] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 26] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 27] Loss: 0.01406 | Accuracy: 92.97% (119/128)
# [Epoch 10] [Batch 28] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 29] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 30] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 31] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 32] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 33] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 34] Loss: 0.01406 | Accuracy: 92.97% (119/128)
# [Epoch 10] [Batch 35] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 36] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 37] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 38] Loss: 0.00156 | Accuracy: 99.22% (127/128)
# [Epoch 10] [Batch 39] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 40] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 41] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 42] Loss: 0.00156 | Accuracy: 99.22% (127/128)
# [Epoch 10] [Batch 43] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 44] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 45] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 46] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 47] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 48] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 49] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 50] Loss: 0.01562 | Accuracy: 92.19% (118/128)
# [Epoch 10] [Batch 51] Loss: 0.00156 | Accuracy: 99.22% (127/128)
# [Epoch 10] [Batch 52] Loss: 0.01719 | Accuracy: 91.41% (117/128)
# [Epoch 10] [Batch 53] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 54] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 55] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 56] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 57] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 58] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 59] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 60] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 61] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 62] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 63] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 64] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 65] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 66] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 67] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 68] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 69] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 70] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 71] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 72] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 73] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 74] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 75] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 76] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 77] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 78] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 79] Loss: 0.01719 | Accuracy: 91.41% (117/128)
# [Epoch 10] [Batch 80] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 81] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 82] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 83] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 84] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 85] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 86] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 87] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 88] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 89] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 90] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 91] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 92] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 93] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 94] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 95] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 96] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 97] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 98] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 99] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 100] Loss: 0.01562 | Accuracy: 92.19% (118/128)
# [Epoch 10] [Batch 101] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 102] Loss: 0.01562 | Accuracy: 92.19% (118/128)
# [Epoch 10] [Batch 103] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 104] Loss: 0.01719 | Accuracy: 91.41% (117/128)
# [Epoch 10] [Batch 105] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 106] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 107] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 108] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 109] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 110] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 111] Loss: 0.01406 | Accuracy: 92.97% (119/128)
# [Epoch 10] [Batch 112] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 113] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 114] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 115] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 116] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 117] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 118] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 119] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 120] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 121] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 122] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 123] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 124] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 125] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 126] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 127] Loss: 0.01719 | Accuracy: 91.41% (117/128)
# [Epoch 10] [Batch 128] Loss: 0.00000 | Accuracy: 100.00% (128/128)
# [Epoch 10] [Batch 129] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 130] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 131] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 132] Loss: 0.01562 | Accuracy: 92.19% (118/128)
# [Epoch 10] [Batch 133] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 134] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 135] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 136] Loss: 0.00156 | Accuracy: 99.22% (127/128)
# [Epoch 10] [Batch 137] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 138] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 139] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 140] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 141] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 142] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 143] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 144] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 145] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 146] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 147] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 148] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 149] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 150] Loss: 0.01406 | Accuracy: 92.97% (119/128)
# [Epoch 10] [Batch 151] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 152] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 153] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 154] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 155] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 156] Loss: 0.01562 | Accuracy: 92.19% (118/128)
# [Epoch 10] [Batch 157] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 158] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 159] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 160] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 161] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 162] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 163] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 164] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 165] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 166] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 167] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 168] Loss: 0.01406 | Accuracy: 92.97% (119/128)
# [Epoch 10] [Batch 169] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 170] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 171] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 172] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 173] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 174] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 175] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 176] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 177] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 178] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 179] Loss: 0.01719 | Accuracy: 91.41% (117/128)
# [Epoch 10] [Batch 180] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 181] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 182] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 183] Loss: 0.01406 | Accuracy: 92.97% (119/128)
# [Epoch 10] [Batch 184] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 185] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 186] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 187] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 188] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 189] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 190] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 191] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 192] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 193] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 194] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 195] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 196] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 197] Loss: 0.01406 | Accuracy: 92.97% (119/128)
# [Epoch 10] [Batch 198] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 199] Loss: 0.01562 | Accuracy: 92.19% (118/128)
# [Epoch 10] [Batch 200] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 201] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 202] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 203] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 204] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 205] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 206] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 207] Loss: 0.02031 | Accuracy: 89.84% (115/128)
# [Epoch 10] [Batch 208] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 209] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 210] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 211] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 212] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 213] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 214] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 215] Loss: 0.01562 | Accuracy: 92.19% (118/128)
# [Epoch 10] [Batch 216] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 217] Loss: 0.01719 | Accuracy: 91.41% (117/128)
# [Epoch 10] [Batch 218] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 219] Loss: 0.00156 | Accuracy: 99.22% (127/128)
# [Epoch 10] [Batch 220] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 221] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 222] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 223] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 224] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 225] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 226] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 227] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 228] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 229] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 230] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 231] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 232] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 233] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 234] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 235] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 236] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 237] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 238] Loss: 0.01406 | Accuracy: 92.97% (119/128)
# [Epoch 10] [Batch 239] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 240] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 241] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 242] Loss: 0.01562 | Accuracy: 92.19% (118/128)
# [Epoch 10] [Batch 243] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 244] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 245] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 246] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 247] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 248] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 249] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 250] Loss: 0.00156 | Accuracy: 99.22% (127/128)
# [Epoch 10] [Batch 251] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 252] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 253] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 254] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 255] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 256] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 257] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 258] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 259] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 260] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 261] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 262] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 263] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 264] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 265] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 266] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 267] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 268] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 269] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 270] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 271] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 272] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 273] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 274] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 275] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 276] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 277] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 278] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 279] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 280] Loss: 0.01406 | Accuracy: 92.97% (119/128)
# [Epoch 10] [Batch 281] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 282] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 283] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 284] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 285] Loss: 0.01562 | Accuracy: 92.19% (118/128)
# [Epoch 10] [Batch 286] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 287] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 288] Loss: 0.01406 | Accuracy: 92.97% (119/128)
# [Epoch 10] [Batch 289] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 290] Loss: 0.00156 | Accuracy: 99.22% (127/128)
# [Epoch 10] [Batch 291] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 292] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 293] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 294] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 295] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 296] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 297] Loss: 0.01406 | Accuracy: 92.97% (119/128)
# [Epoch 10] [Batch 298] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 299] Loss: 0.01406 | Accuracy: 92.97% (119/128)
# [Epoch 10] [Batch 300] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 301] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 302] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 303] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 304] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 305] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 306] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 307] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 308] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 309] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 310] Loss: 0.01562 | Accuracy: 92.19% (118/128)
# [Epoch 10] [Batch 311] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 312] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 313] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 314] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 315] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 316] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 317] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 318] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 319] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 320] Loss: 0.01406 | Accuracy: 92.97% (119/128)
# [Epoch 10] [Batch 321] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 322] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 323] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 324] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 325] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 326] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 327] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 328] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 329] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 330] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 331] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 332] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 333] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 334] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 335] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 336] Loss: 0.01406 | Accuracy: 92.97% (119/128)
# [Epoch 10] [Batch 337] Loss: 0.01875 | Accuracy: 90.62% (116/128)
# [Epoch 10] [Batch 338] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 339] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 340] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 341] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 342] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 343] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 344] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 345] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 346] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 347] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 348] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 349] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 350] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 351] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 352] Loss: 0.01406 | Accuracy: 92.97% (119/128)
# [Epoch 10] [Batch 353] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 354] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 355] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 356] Loss: 0.01562 | Accuracy: 92.19% (118/128)
# [Epoch 10] [Batch 357] Loss: 0.00156 | Accuracy: 99.22% (127/128)
# [Epoch 10] [Batch 358] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 359] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 360] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 361] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 362] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 363] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 364] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 365] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 366] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 367] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 368] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 369] Loss: 0.01875 | Accuracy: 90.62% (116/128)
# [Epoch 10] [Batch 370] Loss: 0.00156 | Accuracy: 99.22% (127/128)
# [Epoch 10] [Batch 371] Loss: 0.01406 | Accuracy: 92.97% (119/128)
# [Epoch 10] [Batch 372] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 373] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 374] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 375] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 376] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 377] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 378] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 379] Loss: 0.00156 | Accuracy: 99.22% (127/128)
# [Epoch 10] [Batch 380] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 381] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 382] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 383] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 384] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 385] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 386] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 387] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 388] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 389] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 390] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 391] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 392] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 393] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 394] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 395] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 396] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 397] Loss: 0.01562 | Accuracy: 92.19% (118/128)
# [Epoch 10] [Batch 398] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 399] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 400] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 401] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 402] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 403] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 404] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 405] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 406] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 407] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 408] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 409] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 410] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 411] Loss: 0.00156 | Accuracy: 99.22% (127/128)
# [Epoch 10] [Batch 412] Loss: 0.01406 | Accuracy: 92.97% (119/128)
# [Epoch 10] [Batch 413] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 414] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 415] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 416] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 417] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 418] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 419] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 420] Loss: 0.01562 | Accuracy: 92.19% (118/128)
# [Epoch 10] [Batch 421] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 422] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 423] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 424] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 425] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 426] Loss: 0.01719 | Accuracy: 91.41% (117/128)
# [Epoch 10] [Batch 427] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 428] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 429] Loss: 0.01406 | Accuracy: 92.97% (119/128)
# [Epoch 10] [Batch 430] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 431] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 432] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 433] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 434] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 435] Loss: 0.01406 | Accuracy: 92.97% (119/128)
# [Epoch 10] [Batch 436] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 437] Loss: 0.00156 | Accuracy: 99.22% (127/128)
# [Epoch 10] [Batch 438] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 439] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 440] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 441] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 442] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 443] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 444] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 445] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 446] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 447] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 448] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 449] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 450] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 451] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 452] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 453] Loss: 0.00625 | Accuracy: 96.88% (124/128)
# [Epoch 10] [Batch 454] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 455] Loss: 0.01094 | Accuracy: 94.53% (121/128)
# [Epoch 10] [Batch 456] Loss: 0.00156 | Accuracy: 99.22% (127/128)
# [Epoch 10] [Batch 457] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 458] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 459] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 460] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 461] Loss: 0.01250 | Accuracy: 93.75% (120/128)
# [Epoch 10] [Batch 462] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 463] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 464] Loss: 0.00469 | Accuracy: 97.66% (125/128)
# [Epoch 10] [Batch 465] Loss: 0.00781 | Accuracy: 96.09% (123/128)
# [Epoch 10] [Batch 466] Loss: 0.00313 | Accuracy: 98.44% (126/128)
# [Epoch 10] [Batch 467] Loss: 0.00938 | Accuracy: 95.31% (122/128)
# [Epoch 10] [Batch 468] Loss: 0.00000 | Accuracy: 100.00% (96/96)
